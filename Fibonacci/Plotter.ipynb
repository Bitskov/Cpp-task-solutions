# %%
import numpy as np
import pandas as pd;
import matplotlib.pyplot as plt

# %%
data1 = pd.read_csv("fast_pow.dat", sep=" ", header=None)
data2 = pd.read_csv("classic.dat", sep=" ", header=None)

# %%
x = np.linspace(0, 100, 100)
y = np.log2(x)
data2[1].plot();
plt.plot(x, y)
#(data2[1] - data1[1]).plot();
# Out:
# c:\users\alexei\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log2

# %%
(data2[1] - data1[1]).plot()
